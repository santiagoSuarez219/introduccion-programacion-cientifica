# %% [markdown]
# <a href="https://colab.research.google.com/github/santiagoSuarez219/introduccion-programacion-cientifica/blob/main/clases/01-introduccion_a_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
userdata.get('GITHUB_TOKEN')

# %% [markdown]
# https://octoverse.github.com/2022/top-programming-languages

# %% [markdown]
# https://survey.stackoverflow.co/2025/technology

# %% [markdown]
# https://www.tiobe.com/tiobe-index/

# %% [markdown]
# https://codingnomads.co/blog/the-best-programming-languages-to-learn/
