# %% [markdown]
# <a href="https://colab.research.google.com/github/santiagoSuarez219/introduccion-programacion-cientifica/blob/main/ejercicios/clase1_ejercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicios

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
nombre_producto = "Cuaderno Argollado"
precio = 2500
esta_disponible = True

# %%
type(nombre_producto)
# Out:
# str

# %%
print(nombre_producto)
# Out:
# Cuaderno Argollado

# %%
# Calcular el IVA del precio de producto y almacenarlo en una variable
iva = precio*0.19
print("Precio del producto: " + str(precio))
print(f"Valor del iva: {iva}")
print(f"El valor total es: {precio + iva}")
# Out:
# Precio del producto: 2500
# Valor del iva: 475.0
# El valor total es: 2975.0

# %%
precio = 15990.0
disponible = True
temperatura = 18.5

print(precio > 20000)          # ¿el precio supera los 20000?
print(precio == 15990.0)       # ¿el precio es exactamente 15990.0?
print(temperatura != 20)       # ¿la temperatura es distinta de 20?
# Out:
# False
# True
# True
